# %%
a=[1,2,3]
try:
    a=int(input("Enter a index:"))
except IndexError:
    print("Index out of range")
else:
    print("Index out of range")
finally:
    print(a)
# Out:
# Index out of range
# 6

# %%
try:
    b=int(input("Enter a num"))
    if b<0:
        raise ValueError("ValueError")
except ValueError :
       print("ValueError")

else:
    print("Value in range")
finally:
    print(b)
# Out:
# Value in range
# 2

# %%
try:
    c = int(input("Enter a num1: "))
    v = int(input("Enter a num2: "))

    if v == 0:
        raise ZeroDivisionError("مينفعش صفر")

    summ = c / v

except ZeroDivisionError as e:
    print("zero division error")

except ValueError:
    print("ValueError")

else:
    print(" summ", summ)
# Out:
# ZeroDivisionError
